# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p = np.arange(2E-14,4E-13,1E-15) #range of mass density in the sun's corona
c=3E8                 #speed of light
u=np.pi*4E-7        #permeability of vaccum
B_values=np.array([5E-5, 8E-5, 1E-4, 1.3E-4])  #earth B field ranges from 25 to 65 microT and it is known that the sun is atleast double the strength.
for B in B_values: 
    V_a=B/np.sqrt(u*p)    #alfven velocity
    plt.plot(p, V_a/np.sqrt(1+(V_a/c)**2), label=B)
    plt.suptitle("Phase Velocity in sun's Corona")
    plt.legend()
    plt.ylabel('Phase Velocity')
    plt.xlabel('Mass Density')
plt.ylim((0,800000))
plt.xlim((2E-14,4E-13))
plt.show()

# %%
p = np.arange(.008,.02,.001) #range of the photosphere mass density
c=3E8   #speed of light
u=np.pi*4E-7 #permeability of vaccum
B_values=np.array([5E-5, 8E-5, 1E-4, 1.3E-4])  #earth B field ranges from 25 to 65 microT and it is known that the sun is atleast double the strength.
for B in B_values: 
    V_a=B/np.sqrt(u*p)    #alfven velocity
    plt.plot(p, V_a/np.sqrt(1+(V_a/c)**2), label=B)
    plt.suptitle("Phase Velocity in the sun's photosphere")
    plt.legend()
    plt.ylabel('Phase Velocity')
    plt.xlabel('Mass Density')
#plt.ylim((0,800000))
#plt.xlim((2E-14,4E-13))
plt.show()

# %%
#Temprature using the phase Velocity of the sun's corona

# %%
#Temprature using the phase Velocity of the sun's photosphere
